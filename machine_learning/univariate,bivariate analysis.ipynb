# %%
from sklearn.datasets import load_iris

# %%
df=load_iris()

# %%
len(df.target)
# Out:
# 150

# %%
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("iris.csv")

# %%
df.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# # univeriate analysis

# %%
df_setosa=df.loc[df['Species']=="Iris-setosa"]
df_setosa.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_setosa=df.loc[df['Species']=="Iris-setosa"]
df_virginica=df.loc[df['Species']=="Iris-virginica"]
df_versicolor=df.loc[df['Species']=="Iris-versicolor"]

# %%
plt.plot(df_setosa["SepalLengthCm"],np.zeros_like(df_setosa["SepalLengthCm"]),"*")
plt.plot(df_virginica["SepalLengthCm"],np.zeros_like(df_virginica["SepalLengthCm"]),"o")
plt.plot(df_versicolor["SepalLengthCm"],np.zeros_like(df_versicolor["SepalLengthCm"]),"o")
plt.xlabel("SepalLengthCm")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
sns.FacetGrid(df,hue="Species",size=5).map(plt.scatter,"SepalLengthCm","SepalWidthCm").add_legend()
plt.show()
# Out:
# c:\users\mahima\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Multiveriate Analysis

# %%
sns.pairplot(df,hue="Species",size=5)
# Out:
# c:\users\mahima\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
